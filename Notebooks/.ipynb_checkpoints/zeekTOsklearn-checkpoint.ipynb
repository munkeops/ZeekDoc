# %%
# Example that demonstrates going from Zeek data to scikit-learn models
from __future__ import print_function
import os
import sys
import argparse

# Third Party Imports
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.cluster import KMeans
import numpy as np

# Local imports
from zat import log_to_dataframe
from zat import dataframe_to_matrix

# Helper method for scatter/beeswarm plot
def jitter(arr):
    stdev = .02*(max(arr)-min(arr))
    return arr + np.random.randn(len(arr)) * stdev

# %%
parser = argparse.ArgumentParser()
parser.add_argument('zeek_log', type=str, help='Specify a zeek log to run ZeekLogReader test on')
args, commands = parser.parse_known_args()

# Check for unknown args
# if commands:
# print('Unrecognized args: %s' % commands)
# sys.exit(1)
args.zeek_log="../portscan/dns.log"

# Sanity check that this is a dns log
if 'dns' not in args.zeek_log:
    print('This example only works with Zeek dns.log files..')
    sys.exit(1)

# File may have a tilde in it
if args.zeek_log:
    args.zeek_log = os.path.expanduser(args.zeek_log)

# Create a Pandas dataframe from the Zeek log
log_to_df = log_to_dataframe.LogToDataFrame()
zeek_df = log_to_df.create_dataframe(args.zeek_log)

# Add query length
zeek_df['query_length'] = zeek_df['query'].str.len()

# Normalize this field
#ql = zeek_df['query_length']
#zeek_df['query_length_norm'] = (ql - ql.min()) / (ql.max()-ql.min())

# These are the features we want (note some of these are categorical!)
features = ['AA', 'RA', 'RD', 'TC', 'Z', 'rejected', 'proto', 'qtype_name', 'rcode_name', 'query_length']
feature_df = zeek_df[features]

# Use the super awesome DataframeToMatrix class (handles categorical data!)
to_matrix = dataframe_to_matrix.DataFrameToMatrix()
zeek_matrix = to_matrix.fit_transform(feature_df)

# Now we're ready for scikit-learn!
# Just some simple stuff for this example, KMeans and PCA
kmeans = KMeans(n_clusters=5).fit_predict(zeek_matrix)
pca = PCA(n_components=2).fit_transform(zeek_matrix)

# Now we can put our ML results back onto our dataframe!
zeek_df['x'] = jitter(pca[:, 0]) # PCA X Column
zeek_df['y'] = jitter(pca[:, 1]) # PCA Y Column
zeek_df['cluster'] = kmeans

# Now use dataframe group by cluster
show_fields = ['query', 'Z', 'proto', 'qtype_name', 'x', 'y', 'cluster']
cluster_groups = zeek_df[show_fields].groupby('cluster')
# Out:
# Normalizing column Z...
# Cannot normalize series (div by 0) so not normalizing...
# Normalizing column query_length...

# %%
# Now print out the details for each cluster
# pd.set_option('display.width', 1000)
for key, group in cluster_groups:
    print('Rows in Cluster: {:d}'.format(len(group)))
    print(group.head(), '\n')
# Out:
# Rows in Cluster: 6
#                                                  query  Z proto qtype_name  \
# ts
# 2020-07-21 05:06:42.054985046  rohanelementaryos.local  0   udp       AAAA
# 2020-07-21 05:06:42.065875053  rohanelementaryos.local  0   udp       AAAA
# 2020-07-21 05:06:42.056361914  rohanelementaryos.local  0   udp       AAAA
# 2020-07-21 05:06:42.067245007  rohanelementaryos.local  0   udp       AAAA
# 2020-07-21 05:06:42.060451984        rohanelementaryos  0   udp       AAAA
#
#                                       x         y  cluster
# ts
# 2020-07-21 05:06:42.054985046  0.589512 -0.725811        0
# 2020-07-21 05:06:42.065875053  0.508623 -0.840792        0
# 2020-07-21 05:06:42.056361914  0.619164 -0.811871        0
# 2020-07-21 05:06:42.067245007  0.525708 -0.839762        0
# 2020-07-21 05:06:42.060451984  0.557042 -0.935939        0
#
# Rows in Cluster: 24
#                                                            query  Z proto  \
# ts
# 2020-07-21 05:00:27.864109039  142.26.168.192.in-addr.arpa.local  0   udp
# 2020-07-21 05:00:27.866831064  142.26.168.192.in-addr.arpa.local  0   udp
# 2020-07-21 05:00:28.888165951  142.26.168.192.in-addr.arpa.local  0   udp
# 2020-07-21 05:00:28.890889168  142.26.168.192.in-addr.arpa.local  0   udp
# 2020-07-21 05:00:27.865610838  142.26.168.192.in-addr.arpa.local  0   udp
#
#                               qtype_name         x         y  cluster
# ts
# 2020-07-21 05:00:27.864109039        PTR -0.355342  0.287676        1
# 2020-07-21 05:00:27.866831064        PTR -0.391998  0.291158        1
# 2020-07-21 05:00:28.888165951        PTR -0.329240  0.316013        1
# 2020-07-21 05:00:28.890889168        PTR -0.346385  0.270248        1
# 2020-07-21 05:00:27.865610838        PTR -0.332030  0.286179        1
#
# Rows in Cluster: 4
#                                                      query  Z proto  \
# ts
# 2020-07-21 04:59:58.985475063  132.29.168.192.in-addr.arpa  0   udp
# 2020-07-21 05:06:41.849042892      rohanelementaryos.local  0   udp
# 2020-07-21 05:06:42.055122137      rohanelementaryos.local  0   udp
# 2020-07-21 05:06:42.056501865      rohanelementaryos.local  0   udp
#
#                               qtype_name         x         y  cluster
# ts
# 2020-07-21 04:59:58.985475063        NaN  2.031127  1.099222        2
# 2020-07-21 05:06:41.849042892        NaN  2.034068  0.917091        2
# 2020-07-21 05:06:42.055122137        NaN  2.016171  0.989095        2
# 2020-07-21 05:06:42.056501865        NaN  2.012926  0.977279        2
#
# Rows in Cluster: 28
#                                                 query  Z proto qtype_name  \
# ts
# 2020-07-21 05:07:52.712644815  _googlecast._tcp.local  0   udp        PTR
# 2020-07-21 05:07:52.714141130  _googlecast._tcp.local  0   udp        PTR
# 2020-07-21 05:07:54.555783987  _googlecast._tcp.local  0   udp        PTR
# 2020-07-21 05:07:53.531778812  _googlecast._tcp.local  0   udp        PTR
# 2020-07-21 05:08:14.626924992  _googlecast._tcp.local  0   udp        PTR
#
#                                       x         y  cluster
# ts
# 2020-07-21 05:07:52.712644815 -0.252787  0.005861        3
# 2020-07-21 05:07:52.714141130 -0.241199 -0.048480        3
# 2020-07-21 05:07:54.555783987 -0.177419  0.022605        3
# 2020-07-21 05:07:53.531778812 -0.213675 -0.013212        3
# 2020-07-21 05:08:14.626924992 -0.265976  0.016310        3
#
# Rows in Cluster: 6
#                                                  query  Z proto qtype_name  \
# ts
# 2020-07-21 05:06:41.848863125  rohanelementaryos.local  0   udp          A
# 2020-07-21 05:06:42.063130140  rohanelementaryos.local  0   udp          A
# 2020-07-21 05:06:41.850378990  rohanelementaryos.local  0   udp          A
# 2020-07-21 05:06:42.064631939  rohanelementaryos.local  0   udp          A
# 2020-07-21 05:06:42.057982922        rohanelementaryos  0   udp          A
#
#                                       x         y  cluster
# ts
# 2020-07-21 05:06:41.848863125  0.616404 -0.804708        4
# 2020-07-21 05:06:42.063130140  0.534723 -0.793570        4
# 2020-07-21 05:06:41.850378990  0.468867 -0.776160        4
# 2020-07-21 05:06:42.064631939  0.454331 -0.759489        4
# 2020-07-21 05:06:42.057982922  0.486826 -0.946066        4
